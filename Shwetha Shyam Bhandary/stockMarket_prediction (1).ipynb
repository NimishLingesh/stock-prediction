# %%
import pandas as pd
import numpy as np

#Here we read all the data from the csv file from drive, keep the backup of the data and see the informations of the same.

stock_data= pd.read_csv('/content/stock_list.csv', header=0, na_values='?')
stock_data_backup= stock_data.copy()
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4417 entries, 0 to 4416
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SecuritiesCode          4417 non-null   int64
#  1   EffectiveDate           4417 non-null   int64
#  2   Name                    4417 non-null   object
#  3   Section/Products        4417 non-null   object
#  4   NewMarketSegment        3772 non-null   object
#  5   33SectorCode            4417 non-null   object
#  6   33SectorName            4417 non-null   object
#  7   17SectorCode            4417 non-null   object
#  8   17SectorName            4417 non-null   object
#  9   NewIndexSeriesSizeCode  4417 non-null   object
#  10  NewIndexSeriesSize      4417 non-null   object
#  11  TradeDate               4121 non-null   float64
#  12  Close                   4121 non-null   float64
#  13  IssuedShares            4121 non-null   float64
# ...

# %%
#Here lets now check which of these data has missing values using .isna()
print(stock_data.isna().any(),"\n")
# Out:
# SecuritiesCode            False
# EffectiveDate             False
# Name                      False
# Section/Products          False
# NewMarketSegment           True
# 33SectorCode              False
# 33SectorName              False
# 17SectorCode              False
# 17SectorName              False
# NewIndexSeriesSizeCode    False
# NewIndexSeriesSize        False
# TradeDate                  True
# Close                      True
# IssuedShares               True
# MarketCapitalization       True
# Universe0                 False
# dtype: bool

# %%
print("NewMarketSegment-> ",stock_data['NewMarketSegment'].isna().sum())
print("TradeDate->",stock_data['TradeDate'].isna().sum())
print("Close->",stock_data['Close'].isna().sum())
print("IssuedShares->",stock_data['IssuedShares'].isna().sum())
print("MarketCapitalization->",stock_data['MarketCapitalization'].isna().sum())
print("-----------------------")
# Out:
# NewMarketSegment->  645
# TradeDate-> 296
# Close-> 296
# IssuedShares-> 296
# MarketCapitalization-> 296
# -----------------------

# %%
print(stock_data['NewMarketSegment'].value_counts())
print(stock_data['NewMarketSegment'].describe())
print("-----------------------")
print(stock_data['TradeDate'].value_counts())
print(stock_data['TradeDate'].describe())
print("-----------------------")
print(stock_data['Close'].value_counts())
print(stock_data['Close'].describe())
print("-----------------------")
print(stock_data['IssuedShares'].value_counts())
print(stock_data['IssuedShares'].describe())
print("-----------------------")
print(stock_data['MarketCapitalization'].value_counts())
print(stock_data['MarketCapitalization'].describe())
print("-----------------------")
# Out:
# Prime Market                       1839
# Standard Market                    1466
# Growth Market                       461
# Growth Market (Foreign Stock)         3
# Standard Market (Foreign Stock)       2
# Prime Market (Foreign Stock)          1
# Name: NewMarketSegment, dtype: int64
# count             3772
# unique               6
# top       Prime Market
# freq              1839
# Name: NewMarketSegment, dtype: object
# -----------------------
# 20211230.0    4049
# 20211229.0      37
# 20211228.0      18
# 20211227.0       6
# 20211220.0       3
# 20211221.0       2
# 20211222.0       2
# 20211223.0       2
# 20211216.0       1
# 20211224.0       1
# Name: TradeDate, dtype: int64
# count    4.121000e+03
# mean     2.021123e+07
# std      5.106468e-01
# min      2.021122e+07
# 25%      2.021123e+07
# 50%      2.021123e+07
# 75%      2.021123e+07
# max      2.021123e+07
# Name: TradeDate, dtype: float64
# -----------------------
# 3180.0    8
# 1007.0    8
# 3160.0    6
# ...

# %%
stock_data['NewMarketSegment'] = stock_data['NewMarketSegment'].replace(np.NaN, stock_data['NewMarketSegment'].mode()[0])
print(stock_data['NewMarketSegment'].isna().sum())
print(stock_data['NewMarketSegment'].value_counts())
print(stock_data['NewMarketSegment'].describe())
print("-----------------------")
#Here lets now check which of these data has missing values using .isna()
print(stock_data.isna().any(),"\n")
print("-----------------------")
stock_data['TradeDate'] = stock_data['TradeDate'].replace(np.NaN, stock_data['TradeDate'].mode()[0])
print(stock_data['TradeDate'].isna().sum())
print(stock_data['TradeDate'].value_counts())
print(stock_data['TradeDate'].describe())
print("-----------------------")
#Here lets now check which of these data has missing values using .isna()
print(stock_data.isna().any(),"\n")
print("-----------------------")
stock_data['Close'] = stock_data['Close'].replace(np.NaN, stock_data['Close'].mode()[0])
print(stock_data['Close'].isna().sum())
print(stock_data['Close'].value_counts())
print(stock_data['Close'].describe())
print("-----------------------")
#Here lets now check which of these data has missing values using .isna()
print(stock_data.isna().any(),"\n")
print("-----------------------")
stock_data['IssuedShares'] = stock_data['IssuedShares'].replace(np.NaN, stock_data['IssuedShares'].mode()[0])
print(stock_data['IssuedShares'].isna().sum())
print(stock_data['IssuedShares'].value_counts())
print(stock_data['IssuedShares'].describe())
print("-----------------------")
#Here lets now check which of these data has missing values using .isna()
print(stock_data.isna().any(),"\n")
print("-----------------------")
stock_data['MarketCapitalization'] = stock_data['MarketCapitalization'].replace(np.NaN, stock_data['MarketCapitalization'].mode()[0])
print(stock_data['MarketCapitalization'].isna().sum())
print(stock_data['MarketCapitalization'].value_counts())
print(stock_data['MarketCapitalization'].describe())
print("-----------------------")
#Here lets now check which of these data has missing values using .isna()
print(stock_data.isna().any(),"\n")
print("-----------------------")

def featuring_train(data):
    # string to datetime
    data['EffectiveDate'] = pd.to_datetime(data['EffectiveDate'])
    data['TradeDate'] = pd.to_datetime(data['TradeDate'])
    return data
  
# featuring
data = featuring_train(stock_data)
# Out:
# 0
# Prime Market                       2484
# Standard Market                    1466
# Growth Market                       461
# Growth Market (Foreign Stock)         3
# Standard Market (Foreign Stock)       2
# Prime Market (Foreign Stock)          1
# Name: NewMarketSegment, dtype: int64
# count             4417
# unique               6
# top       Prime Market
# freq              2484
# Name: NewMarketSegment, dtype: object
# -----------------------
# SecuritiesCode            False
# EffectiveDate             False
# Name                      False
# Section/Products          False
# NewMarketSegment          False
# 33SectorCode              False
# 33SectorName              False
# 17SectorCode              False
# 17SectorName              False
# NewIndexSeriesSizeCode    False
# NewIndexSeriesSize        False
# TradeDate                 False
# Close                     False
# IssuedShares              False
# MarketCapitalization       True
# ...

# %%
#Encoding data
from sklearn import preprocessing
from sklearn.preprocessing import binarize, LabelEncoder, MinMaxScaler
labelDict = {}

for feature in stock_data:
    le = preprocessing.LabelEncoder()
    le.fit(stock_data[feature])
    le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    stock_data[feature] = le.transform(stock_data[feature])
    # Get labels
    labelKey = 'label_' + feature
    labelValue = [*le_name_mapping]
    labelDict[labelKey] =labelValue
    
for key, value in labelDict.items():     
    print(key, value)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#correlation matrix
corrmat = stock_data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(stock_data)
